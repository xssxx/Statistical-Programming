# %% [markdown]
# # แบบฝึกหัด 7

# %% [markdown]
# ---

# %%
import numpy as np
from scipy import stats
from statsmodels.stats.weightstats import ztest

# %% [markdown]
# 7.1 จากการเก็บข้อมูลของบูธร้านค้าร้านหนึ่งในงานเกษตรแฟร์โดยสุ่มตัวอย่างลูกค้ามาทั้งหมด 200 คน พบว่ามีอายุเฉลี่ย 42.8 ปี ส่วนเบี่ยงเบนมาตราฐาน 6.89 ปี ผู้ประกอบการร้านแห่งนี้จึงตั้งสมมุติฐานว่า ลูกค้าของทางร้านมีอายุเฉลี่ยสูงกว่า 40 ปี ที่ระดับนัยสำคัญ 0.01 สมมุติฐานนี้ถูกต้องหรือไม่ หากกำหนดให้การแจกแจงของอายุเป็นแบบปกติ

# %%
#แสดงวิธีทำ
n = 200
x_bar = 42.8
s = 6.89
mu0 = 40

z_cal = (x_bar - mu0) / (s / np.sqrt(n)) # 5.747
z_cri = stats.norm.isf(0.01) # 2.326
p_val = stats.norm.sf(z_cal) # 4.537557863298819e-09

# print(z_cal, z_cri, p_val, sep='\n')
print("ค่า p-value > ค่าระดับนัยสำคัญ จึงยอมรับสมมติฐานหลัก นั่นคือ ลูกค้าของทางร้านมีอายุเฉลี่ยสูงกว่า 40 ปีเป็นเท็จ")
# Out:
# ค่า p-value > ค่าระดับนัยสำคัญ จึงยอมรับสมมติฐานหลัก นั่นคือ ลูกค้าของทางร้านมีอายุเฉลี่ยสูงกว่า 40 ปีเป็นเท็จ

# %% [markdown]
# ###

# %% [markdown]
# 7.2 สุ่มตัวอย่างผลิตภัณฑ์ซักล้างยี่ห้อหนึ่งมาจำนวน 8 ชิ้นเพื่อวัดปริมาณสารพิษ พบว่าได้ปริมาณดังนี้ (10<sup>6</sup>ppm) 15, 8, 10, 13, 6, 16, 11, 18 จงทดสอบว่าปริมาณสารพิษของผลิตภัณฑ์ซักล้างยี่ห้อนี้มากกว่าหรือเท่ากับ (≥) 18x10<sup>6</sup>ppm ที่ระดับนัยสำคัญ 0.05 หรือไม่ หากกำหนดให้ปริมาณสารพิษชนิดนี้มีการแจกแจงแบบปกติ

# %%
#แสดงวิธีทำ
samples = [15, 8, 10, 13, 6, 16, 11, 18]
n = 8
x_bar = np.mean(samples)
s = np.std(samples, ddof=1)
mu0 = 18

t_cal = (x_bar - mu0) / (s / np.sqrt(n)) # -4.032335130364934
t_cri = stats.t.ppf(0.05, df=n-1) # -1.8945786050613054
p_val = stats.t.cdf(t_cal, df=n-1) # 0.0024905124764684917

# print(t_cal, t_cri, p_val, sep='\n')
print("ค่า p-value < ค่าระดับนัยสำคัญ จึงปฎิเสธสมมติฐานหลัก นั่นคือ ปริมาณสารพิษของผลิตภัณฑ์ซักล้างยี่ห้อนี้มากกว่าหรือเท่ากับ (≥) 18x10^6 ppm เป็นเท็จ")
# Out:
# ค่า p-value < ค่าระดับนัยสำคัญ จึงปฎิเสธสมมติฐานหลัก นั่นคือ ปริมาณสารพิษของผลิตภัณฑ์ซักล้างยี่ห้อนี้มากกว่าหรือเท่ากับ (≥) 18x10^6 ppm เป็นเท็จ

# %% [markdown]
# ###

# %% [markdown]
# 7.3 ทำการ ping 158.108.216.5 จำนวน 10 ครั้ง ได้ระยะเวลาในหน่วย ms (milliseconds) ดังนี้ 28.2, 26.5, 30.7, 24.1, 25.3, 29.2, 21.6, 26.7, 23.4, 27.3 จงทดสอบว่าระยะเวลาที่ใช้ในการ ping โดยเฉลี่ยมีค่าเท่ากับ 26 ms หรือไม่ที่ระดับนัยสำคัญ 0.05 หากทราบมาว่าระยะเวลาที่ใช้ในการ ping มีการแจกแจงแบบปกติ

# %%
#แสดงวิธีทำ
ping = [28.2, 26.5, 30.7, 24.1, 25.3, 29.2, 21.6, 26.7, 23.4, 27.3]
n = 10
x_bar = np.mean(ping)
s = np.std(ping, ddof=1)
mu0 = 26

t_cal = (x_bar - mu0) / (s / np.sqrt(n)) # 0.34282294000695074
t_cri = stats.t.isf(0.05/2, df=n-1) # 2.262157162740992
p_val = 2 * stats.t.sf(abs(t_cal), df=n-1) # 0.7396027657579755

# print(t_cal, t_cri, p_val, sep='\n')
print("ค่า p-value > ค่าระดับนัยสำคัญ จึงยอมรับสมมติฐานหลัก นั่นคือ ระยะเวลาที่ใช้ในการ ping โดยเฉลี่ยมีค่าเท่ากับ 26 ms เป็นจริง")
# Out:
# ค่า p-value > ค่าระดับนัยสำคัญ จึงยอมรับสมมติฐานหลัก นั่นคือ ระยะเวลาที่ใช้ในการ ping โดยเฉลี่ยมีค่าเท่ากับ 26 ms เป็นจริง

# %% [markdown]
# ###

# %% [markdown]
# 7.4 ห้องปฏิบัติการ 2 แห่ง สุ่มตรวจสอบปริมาณนิโคตินในบุหรี่ยี่ห้อหนึ่งด้ผลการวิเคราะห์ปริมาณนิโคติน (มิลลิกรัม) ดังนี้
# ห้องปฏิบัติการ1: 56, 37, 61, 56, 65, 41, 63, 50, 42
# ห้องปฏิบัติการ2: 46, 25, 46, 64, 34, 56
# จงทดสอบสมมติฐานว่าปริมาณนิโคตินที่วิเคราะห์ได้โดยห้องปฏิบัติการสองแห่งนี้ไม่แตกต่างกัน
# ที่ระดับนัยสำคัญ 0.10 หากกำหนดให้ปริมาณนิโคตินในบุหรี่ที่วิเคราะห์ได้โดยห้องปฏิบัติการทั้งสองมีการ
# แจกแจงแบบปกติที่มีค่าความแปรปรวนเท่ากัน

# %%
#แสดงวิธีทำ
lab1 = [56, 37, 61, 56, 65, 41, 63, 50, 42]
lab2 = [46, 25, 46, 64, 34, 56]

n1 = len(lab1)
n2 = len(lab2)
df = n1 + n2 - 2

x_bar1 = np.mean(lab1)
x_bar2 = np.mean(lab2)

s2_1 = np.var(lab1, ddof=1)
s2_2 = np.var(lab2, ddof=1)
s2p = ((n1-1)*s2_1 + (n2-1)*s2_2) / df

t_cal = ((x_bar1 - x_bar2) - 0) / np.sqrt(s2p * (1/n1 + 1/n2))

p_val = 2 * stats.t.sf(abs(t_cal), df=df) # 0.2757530487532558

print("ค่า p-value > ค่าระดับนัยสำคัญ จึงยอมรับสมมติฐานหลัก นั่นคือ ปริมาณนิโคตินที่วิเคราะห์ได้โดยห้องปฏิบัติการสองแห่งนี้ไม่แตกต่างกัน เป็นเท็จ")
# Out:
# ค่า p-value > ค่าระดับนัยสำคัญ จึงยอมรับสมมติฐานหลัก นั่นคือ ปริมาณนิโคตินที่วิเคราะห์ได้โดยห้องปฏิบัติการสองแห่งนี้ไม่แตกต่างกัน เป็นเท็จ

# %% [markdown]
# ###

# %% [markdown]
# 7.5 เครื่องใช้พลาสติกชนิดหนึ่ง ผลิตโดยกระบวนการผลิตแตกต่างกัน 2 วิธี คือ A และ B ต้องการตรวจสอบความ
# เหนียวของพลาสติกที่ผลิตได้โดยทั้งสองกระบวนการนี้ว่าแตกต่างกันหรือไม่ จึงสุ่มตัวอย่าง
# ผลิตภัณฑ์จากกระบวนการผลิต A มา 30 ชิ้น ทดสอบและคำนวณค่าความเหนียวเฉลี่ยได้เป็น
# 28.3 ส่วนเบี่ยงเบนมาตรฐาน 3.3 เมื่อสุ่มผลิตภัณฑ์จากกระบวนการผลิต B 40 ชิ้น คำนวณค่าความเหนียวเฉลี่ยได้เป็น 26.7 ส่วนเบี่ยงเบนมาตรฐานเป็น 4.9 หากการทดสอบโดยใช้ระดับนัยสำคัญ 0.05

# %%
#แสดงวิธีทำ
nA= 30
x_barA = 28.3
sA = 3.3

nB = 40
x_barB = 26.7
sB = 4.9

df = nA + nB - 2

s2p = ((nA-1)*sA + (nB-1)*sB) / df

t_cal = ((x_barA - x_barB) - 0 / np.sqrt(s2p))

p_val = 2 * stats.t.sf(abs(t_cal), df=df) # 0.11423482016161057

print("ค่า p-value > ค่าระดับนัยสำคัญ จึงยอมรับสมมติฐานหลัก นั่นคือ ความเหนียวของพลาสติกที่ผลิตได้โดยทั้งสองกระบวนการนี้ ไม่แตกต่างกัน (=)")
# Out:
# ค่า p-value > ค่าระดับนัยสำคัญ จึงยอมรับสมมติฐานหลัก นั่นคือ ความเหนียวของพลาสติกที่ผลิตได้โดยทั้งสองกระบวนการนี้ ไม่แตกต่างกัน (=)
